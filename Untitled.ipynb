# %% [markdown]
# %%html
# <style>
#   .my-class {
#     color: red;
#     font-size: 14px;
#   }
#   /* Example label style */
#   .lang-label {
#     color: gray;
#     font-size: 19px;
#     position: absolute;
#     top: 0.5em;
#     left: 1em;
#     background: #f8f8f8;
#     border: 1px solid #ddd;
#     border-radius: 3px;
#     padding: 0 6px;
#   }
#   .code-container {
#     position: relative;
#     margin-bottom: 1em;
#   }
#   .code-container pre {
#     margin-top: 1.5em; /* make room for the label */
#   }
# </style>
#
# <div>
#   <h1>Project Code Snippets</h1>
#
#   <h2>Step 1</h2>
#   <h3>After reviewing the suggested references. Generate a document that covers the following elements:</h3>
#
#   <div class="code-container">
#     <span class="lang-label">Batch</span>
#     <pre><code class="language-batch">
# use unadTask2DB
#     </code></pre>
#   </div>
#
#   <div class="code-container">
#     <span class="lang-label">js</span>
#     <pre><code class="language-javascript">
# db.insert.many([
#   {
#     "Firstname": "Walter",
#     "Age": 26,
#     "Alias": "Developer",
#     "Information": {
#       "Subject": "History",
#       "Grade": "B"
#     }
#   },
#   {
#     "Firstname": "Rian",
#     "Age": 45,
#     "Alias": "Data Engineer",
#     "Information": {
#       "Subject": "Physics",
#       "Grade": "A"
#     }
#   },
#   {
#     "Firstname": "Johana",
#     "Age": 46,
#     "Alias": "Data Scientist",
#     "Information": {
#       "Subject": "Physics",
#       "Grade": "A+"
#     }
#   }
# ]);
#     </code></pre>
#   </div>
#
#   <div class="code-container">
#     <span class="lang-label">py</span>
#     <pre><code class="language-python">
# def greet():
#     print("Hello, World!")
#
# greet()
#     </code></pre>
#   </div>
#
#   <h2>SQL Server Code</h2>
#   <div class="code-container">
#     <span class="lang-label">sql</span>
#     <pre><code class="language-sql">
# SELECT TOP 10 *
# FROM Customers
# WHERE Country = 'USA';
#     </code></pre>
#   </div>
# </div>
